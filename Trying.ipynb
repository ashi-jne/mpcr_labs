# %% [markdown]
# <a href="https://colab.research.google.com/github/ashi-jne/mpcr_labs/blob/main/Trying.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
data = np.random.rand(3,4)
import matplotlib.pyplot as plt
plt.imshow(data)

# %%
data
# Out:
# array([[0.4890597 , 0.22529862, 0.29793557, 0.78943858],
#        [0.28702438, 0.95762325, 0.0074013 , 0.44135006],
#        [0.14276721, 0.06926519, 0.66461481, 0.59193043]])
